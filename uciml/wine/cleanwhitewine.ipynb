# %%
import pandas as pd 
import matplotlib as plt
import csv
import json
import numpy as np

# %%
whitewine = pd.read_csv("data/winequality-white.csv")
whitewine
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# ...                                                 ...
# 4893  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4894  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4895  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4896  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4897  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...
#
# [4898 rows x 1 columns]

# %%
# whitewine['fixed acidity'] = whitewine.filter(regex=("fixed acidity.*"))
# whitewine['fixed acidity']

# %%
testdf = pd.DataFrame(np.vstack([whitewine.columns, whitewine]))
testdf
# Out:
#                                                       0
# 0     fixed acidity;"volatile acidity";"citric acid"...
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# ...                                                 ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...
#
# [4899 rows x 1 columns]

# %%
testdf['fixed acidity'] = testdf[0].str.split(';').str[0]

# %%
testdf
# Out:
#                                                       0  fixed acidity
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
# [4899 rows x 2 columns]

# %%
testdf['volatile acidity'] = testdf[0].str.split(';').str[1]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity
# 0     "volatile acidity"
# 1                   0.27
# 2                    0.3
# ...

# %%
testdf['citric acidity'] = testdf[0].str.split(';').str[2]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity
# 0     "volatile acidity"  "citric acid"
# ...

# %%
testdf['residual sugar'] = testdf[0].str.split(';').str[3]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity    residual sugar
# ...

# %%
testdf['chlorides'] = testdf[0].str.split(';').str[4]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity    residual sugar    chlorides
# ...

# %%
testdf['free sulfur dioxide'] = testdf[0].str.split(';').str[5]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity    residual sugar    chlorides  \
# ...

# %%
testdf['total sulfur dioxide'] = testdf[0].str.split(';').str[6]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity    residual sugar    chlorides  \
# ...

# %%
testdf['density'] = testdf[0].str.split(';').str[7]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity    residual sugar    chlorides  \
# ...

# %%
testdf['pH'] = testdf[0].str.split(';').str[8]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity    residual sugar    chlorides  \
# ...

# %%
testdf['sulphates'] = testdf[0].str.split(';').str[9]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity    residual sugar    chlorides  \
# ...

# %%
testdf['alchohol'] = testdf[0].str.split(';').str[10]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity    residual sugar    chlorides  \
# ...

# %%
testdf['quality'] = testdf[0].str.split(';').str[11]

# %%
testdf
# Out:
#                                                       0  fixed acidity  \
# 0     fixed acidity;"volatile acidity";"citric acid"...  fixed acidity
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6              7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...            6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...            8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...            7.2
# ...                                                 ...            ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...            6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...            6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....            6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...            5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...              6
#
#         volatile acidity citric acidity    residual sugar    chlorides  \
# ...

# %%
cleanwine = testdf.drop([0])
cleanwine
# Out:
#                                                       0 fixed acidity  \
# 1      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6             7
# 2     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...           6.3
# 3     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...           8.1
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...           7.2
# 5     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...           7.2
# ...                                                 ...           ...
# 4894  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...           6.2
# 4895  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...           6.6
# 4896  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....           6.5
# 4897  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...           5.5
# 4898  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...             6
#
#      volatile acidity citric acidity residual sugar chlorides  \
# 1                0.27           0.36           20.7     0.045
# ...

# %%
cleanwine = cleanwine.drop(columns=[0])
cleanwine
# Out:
#      fixed acidity volatile acidity citric acidity residual sugar chlorides  \
# 1                7             0.27           0.36           20.7     0.045
# 2              6.3              0.3           0.34            1.6     0.049
# 3              8.1             0.28            0.4            6.9      0.05
# 4              7.2             0.23           0.32            8.5     0.058
# 5              7.2             0.23           0.32            8.5     0.058
# ...            ...              ...            ...            ...       ...
# 4894           6.2             0.21           0.29            1.6     0.039
# 4895           6.6             0.32           0.36              8     0.047
# 4896           6.5             0.24           0.19            1.2     0.041
# 4897           5.5             0.29            0.3            1.1     0.022
# 4898             6             0.21           0.38            0.8      0.02
#
# ...

# %%
cleanwine = cleanwine.reset_index()
cleanwine
# Out:
#       index fixed acidity volatile acidity citric acidity residual sugar  \
# 0         1             7             0.27           0.36           20.7
# 1         2           6.3              0.3           0.34            1.6
# 2         3           8.1             0.28            0.4            6.9
# 3         4           7.2             0.23           0.32            8.5
# 4         5           7.2             0.23           0.32            8.5
# ...     ...           ...              ...            ...            ...
# 4893   4894           6.2             0.21           0.29            1.6
# 4894   4895           6.6             0.32           0.36              8
# 4895   4896           6.5             0.24           0.19            1.2
# 4896   4897           5.5             0.29            0.3            1.1
# 4897   4898             6             0.21           0.38            0.8
#
#      chlorides free sulfur dioxide total sulfur dioxide  density    pH  \
# ...

# %%
cleanwine = cleanwine.drop(columns=['index'])
cleanwine
# Out:
#      fixed acidity volatile acidity citric acidity residual sugar chlorides  \
# 0                7             0.27           0.36           20.7     0.045
# 1              6.3              0.3           0.34            1.6     0.049
# 2              8.1             0.28            0.4            6.9      0.05
# 3              7.2             0.23           0.32            8.5     0.058
# 4              7.2             0.23           0.32            8.5     0.058
# ...            ...              ...            ...            ...       ...
# 4893           6.2             0.21           0.29            1.6     0.039
# 4894           6.6             0.32           0.36              8     0.047
# 4895           6.5             0.24           0.19            1.2     0.041
# 4896           5.5             0.29            0.3            1.1     0.022
# 4897             6             0.21           0.38            0.8      0.02
#
# ...

# %%
cleanwine.dtypes
# Out:
# fixed acidity           object
# volatile acidity        object
# citric acidity          object
# residual sugar          object
# chlorides               object
# free sulfur dioxide     object
# total sulfur dioxide    object
# density                 object
# pH                      object
# sulphates               object
# alchohol                object
# quality                 object
# dtype: object

# %%
cleanwine2 = cleanwine

# %%
cleanwine2 = cleanwine2.astype(float)
cleanwine2
# Out:
#       fixed acidity  volatile acidity  citric acidity  residual sugar  \
# 0               7.0              0.27            0.36            20.7
# 1               6.3              0.30            0.34             1.6
# 2               8.1              0.28            0.40             6.9
# 3               7.2              0.23            0.32             8.5
# 4               7.2              0.23            0.32             8.5
# ...             ...               ...             ...             ...
# 4893            6.2              0.21            0.29             1.6
# 4894            6.6              0.32            0.36             8.0
# 4895            6.5              0.24            0.19             1.2
# 4896            5.5              0.29            0.30             1.1
# 4897            6.0              0.21            0.38             0.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
cleanwine2.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acidity          float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alchohol                float64
# quality                 float64
# dtype: object

# %%
cleanwine2 = cleanwine2.astype(int)

# %%
cleanwine2.dtypes
# Out:
# fixed acidity           int32
# volatile acidity        int32
# citric acidity          int32
# residual sugar          int32
# chlorides               int32
# free sulfur dioxide     int32
# total sulfur dioxide    int32
# density                 int32
# pH                      int32
# sulphates               int32
# alchohol                int32
# quality                 int32
# dtype: object

# %%
cleanwine2['quality'].plot()
# Out:
# <AxesSubplot: >
